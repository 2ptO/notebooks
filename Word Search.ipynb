# %% [markdown]
# ### [Word Search](https://leetcode.com/problems/word-search/description/)
#
# Given a 2D board and a word, find if the word exists in the grid.
#
# The word can be constructed from letters of sequentially adjacent cell, where "adjacent" cells are those horizontally or vertically neighboring. The same letter cell may not be used more than once.
#
# Example:
#
# ```
# board =
# [
#   ['A','B','C','E'],
#   ['S','F','C','S'],
#   ['A','D','E','E']
# ]
#
# Given word = "ABCCED", return true.
# Given word = "SEE", return true.
# Given word = "ABCB", return false.
# ```

# %%
class Solution(object):
    def exist(self, board, word):
        """
        :type board: List[List[str]]
        :type word: str
        :rtype: bool
        """
        # backtracking
        #   cell matches with a char.. next char can be in four possible places
        #   one on the left, right, above and below
        #   if at least one match is found, move in that direction. but hold on.
        #   if moving in that direction, finds a word then its ok..return true.
        #   if it doesn't find a word, then find if another match is there. 
        # if cell doesn't match, then move horizontally
        # if cell match, but next char doesn't match then ? look for another start? look for whole word again
        # 
        # I have to construct the word from the board
        # at each cell, check wehther the constructed word == word, return True
        #
        # check for the formation of the word from every cell // need two for loops
        # check function separate.. that probably have to use recursion
        #
        # what if I come to the same cell again?
        # // need to keep track of cell which are already visited
        
        # edge cases 
        if not board:
            return False
        
        if not word:
            return True
        
        def checkWord(board, word, wordPos, row, column, visitedCells):
            if wordPos == len(word):
                # we found all the characters
                return True
            
            # check for row and column boundaries
            if row < 0 or row >= len(board):
                return False
            
            if column < 0 or column >= len(board[0]):
                return False
            
            # if visited this already, quit.
            if visitedCells[row][column]:
                return False
            
            # if cell doesn't match the current character in word,
            # then also quit
            if word[wordPos] != board[row][column]:
                return False
            
            # ok.. we passed all the checks.
            # now check the neighbors
            # but before that, mark this cell as visited to avoid
            # infinite recursion.b
            
            visitedCells[row][column] = True
            
            # Do not check additonal cells unnecessarily
            cellNext = checkWord(board, word, wordPos+1, row, column + 1, visitedCells)
            cellPrev = cellNext or checkWord(board, word, wordPos+1, row, column - 1, visitedCells)
            cellAbove = cellPrev or checkWord(board, word, wordPos+1, row - 1, column, visitedCells)
            cellBelow = cellAbove or checkWord(board, word, wordPos+1, row + 1, column, visitedCells)
            
            # Turn off visited for next iteration
            visitedCells[row][column] = False
            
            # if we found the remainder of the word from any of the adjacent
            # cells, return True
            return (cellNext or cellPrev or cellAbove or cellBelow)
        
        
        # 2-D board. so number of rows must be equal to number of columns
        rows = len(board)
        columns = len(board[0])
        visitedCells = [[False for _ in range(columns)] for _ in range(rows)]
        
        for row in range(rows):
            for column in range(columns):
                if checkWord(board, word, 0, row, column, visitedCells):
                    return True
        
        return False
                # if word doesn't exist from current cell, move to next cell

# %%
longBoard = [["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a"],["a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","a","b"]]
longWord = "..."

testBoard =[
    ['A','B','C','E'],
    ['S','F','C','S'],
    ['A','D','E','E']
]

testWords = ["ABCCED", "SEE", "BABA", "", "X"]

s = Solution()

def testSolution(s, board, words):
    for word in words:
        s.exist(board, word)

# %timeit testSolution(s, testBoard, testWords)
# %timeit testSolution(s, longBoard, longWord)
