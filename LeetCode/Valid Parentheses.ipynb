# %% [markdown]
# ### [Valid Parantheses](https://leetcode.com/problems/valid-parentheses/)
#
# Given a string containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
# Note that an empty string is also considered valid.
#
# Example 1:
# ```
# Input: "()"
# Output: true
# ```
#
# Example 2:
# ```
# Input: "()[]{}"
# Output: true
# ```
#
# Example 3:
# ```
# Input: "(]"
# Output: false
# ```
#
# Example 4:
# ```
# Input: "([)]"
# Output: false
# ```
#
# Example 5:
# ```
# Input: "{[]}"
# Output: true
# ```

# %%
class Solution:
    def isValid(self, s: str) -> bool:
        # string containing only ({[]})
        # determine if string is valid 
        #   matching closing bracket for each open bracket
        
        
        # scan string s
        #   can use stack to keep track of most recent open bracket
        #   if char is close bracket:
        #       top of the stack must be matching open bracket
        #   else:
        #       push char into stack
        
        # need a mapping between closing and open bracket
        matching_open = {
            "}" : "{",
            "]" : "[",
            ")" : "("
        }
        
        open_brackets = frozenset(matching_open.values())
        closing_brackets = frozenset(matching_open.keys())
        
        stack = []
        
        for bracket in s:
            if bracket in open_brackets:
                stack.append(bracket)
            else:
                # stack must not be empty and top of the stack
                # must be matching open bracket for the current open bracket
                if stack and stack[-1] == matching_open[bracket]:
                    stack.pop()
                    continue
                else:
                    return False
        
        # stack must be empty if the string is valid
        return True if not stack else False

# %%
tests = {
    "tests": [
        {
            "input": "()",
            "output": True

        },
        {
            "input": "()[]{}",
            "output": True

        },
        {
            "input": "(]",
            "output": False

        },
        {
            "input": "([)]",
            "output": False

        },
        {
            "input": "{[]}",
            "output": True

        }
    ]
}

# %%
def run_tests(tests):
    s = Solution()
    for test in tests["tests"]:
        assert(s.isValid(test["input"]) == test["output"])

# %%
run_tests(tests)
